# %%
from PIL import Image
BLACK_GRAD = (34, 34, 34)
BLACK = (0, 0, 0)
WHITE = (255, 255, 255)
BRICK_BROWN = (189, 68, 0)
im = Image.open('test.png', 'r')
width, height = im.size
im2 = Image.open('test.png', 'r')
im2 = im2.convert('RGB')
pix_val = im.load()
new_pix_val = im2.load()
pix_dict = {}
for y in range(height):
    for x in range(width):
        if y > 340 and y < 370:
            new_pix_val[x, y] = (0, 0, 0)
        elif y < 65:
            new_pix_val[x, y] = (0, 0, 0)
        if (new_pix_val[x, y][0], new_pix_val[x, y][1], new_pix_val[x, y][2]) == BLACK:
            continue
        elif (new_pix_val[x, y][0], new_pix_val[x, y][1], new_pix_val[x, y][2]) == WHITE:
            continue
        elif (new_pix_val[x, y][0], new_pix_val[x, y][1], new_pix_val[x, y][2]) == BRICK_BROWN:
            continue
        else:           
            new_pix_val[x, y] = (0, 0, 0)
im2.save('out.png')

# %%
im2 = Image.open('sp.png', 'r')
im2.convert('RGB')
width, height = im2.size
color = []
pix_val = im2.load()
new_pix_dict = {}
im3 = Image.new('RGB', (320, 240), 'black')
new_pix_val = im3.load()


for y in range(240):
    for x in range(320):
        new_pix_val[x, y] = (pix_val[int(x/320*width), int(y/240*height)][0] & 240, pix_val[int(x/320*width), int(y/240*height)][1] & 240, pix_val[int(x/320*width), int(y/240*height)][2] & 240)
im3.save('sp_out22.png')


for y in range(240):
    for x in range(320):
        new_pix_dict[x, y] = (format((int(new_pix_val[x, y][0] & 240) >> 4), 'x') + format((int(new_pix_val[x, y][1] & 240) >> 4), 'x') + format((int(new_pix_val[x, y][2] & 240) >> 4), 'x'))
        
        if new_pix_dict[x, y] not in color:
            color.append(new_pix_dict[x, y])
print(color)
for x in range(320):
    if new_pix_dict[x, 160] != '660' and new_pix_dict[x, 160] != 'ee9' and new_pix_dict[x, 160] != 'bb0':
        print(x, '160')
print(new_pix_dict[])
file4 = open('sp2.txt', 'w')
for y in range(240):
    for x in range(320):
        file4.write(new_pix_dict[x, y]+'\n')
file4.close()
print("Done!")
# Out:
# ['222', '6af', '000', 'fff', '603', 'ee9', 'b27', '16d', 'f87', '666', 'bbb', 'c7f', '4cd', '8d0', '380', '916', 'd29', '72f', '660', 'bb0', '5ef', 'fa9', 'f76', '777', '555', '999']
# 0 160
# 1 160
# 18 160
# 19 160
# 36 160
# 37 160
# 55 160
# 74 160
# 91 160
# 92 160
# 109 160
# 110 160
# 128 160
# 129 160
# 147 160
# 148 160
# 149 160
# 150 160
# 151 160
# 152 160
# 153 160
# 154 160
# 155 160
# 156 160
# 157 160
# 158 160
# 159 160
# 160 160
# 161 160
# 162 160
# 163 160
# 164 160
# 165 160
# 166 160
# 167 160
# 168 160
# 169 160
# 170 160
# 171 160
# 172 160
# 173 160
# 174 160
# 175 160
# 176 160
# 177 160
# 178 160
# 179 160
# 180 160
# 181 160
# 182 160
# 183 160
# 184 160
# 185 160
# 186 160
# 187 160
# 188 160
# 189 160
# 190 160
# 191 160
# 192 160
# 193 160
# 194 160
# 195 160
# 196 160
# 197 160
# 198 160
# 199 160
# 200 160
# 201 160
# 202 160
# 203 160
# 204 160
# 205 160
# 206 160
# 207 160
# 208 160
# 209 160
# 210 160
# 211 160
# 212 160
# 213 160
# 214 160
# 215 160
# 216 160
# 217 160
# 218 160
# 219 160
# 220 160
# 221 160
# 222 160
# 223 160
# 224 160
# 225 160
# 226 160
# 227 160
# 228 160
# 229 160
# 230 160
# 231 160
# 232 160
# 233 160
# 234 160
# 235 160
# 236 160
# 237 160
# 238 160
# 239 160
# 240 160
# 241 160
# 242 160
# 243 160
# 244 160
# 245 160
# 246 160
# 248 160
# 249 160
# 251 160
# 252 160
# 253 160
# 254 160
# 255 160
# 256 160
# 257 160
# 258 160
# 259 160
# 260 160
# 261 160
# 262 160
# 263 160
# 264 160
# 265 160
# 266 160
# 267 160
# 268 160
# 269 160
# 270 160
# 271 160
# 272 160
# 273 160
# 274 160
# 275 160
# 276 160
# 277 160
# 278 160
# 279 160
# 280 160
# 281 160
# 282 160
# 283 160
# 284 160
# 285 160
# 286 160
# 287 160
# 288 160
# 289 160
# 290 160
# 291 160
# 292 160
# 293 160
# 294 160
# 295 160
# 296 160
# 297 160
# 298 160
# 299 160
# 300 160
# 301 160
# 302 160
# 303 160
# 304 160
# 305 160
# 306 160
# 307 160
# 308 160
# 309 160
# 310 160
# 311 160
# 312 160
# 313 160
# 314 160
# 315 160
# 316 160
# 317 160
# 318 160
# 319 160
# Done!

# %%
pix_dict = {}
im3 = Image.open('out2.png', 'r')
im3.convert('RGB')
width, height = im2.size
pix_val = im2.load()
for y in range(height):
    for x in range(width):
        pix_dict[x, y] = (format((int(pix_val[x, y][0] & 240) >> 4), 'x') + format((int(pix_val[x, y][1] & 240) >> 4), 'x') + format((int(pix_val[x, y][2] & 240) >> 4), 'x'))
        
file1 = open('background.sv', 'w')
file1.write('module Background (\n')
file1.write('    input  logic clk, \n')
file1.write('    input  logic [9:0] x, \n')
file1.write('    input  logic [9:0] y, \n')
file1.write('    output logic [11:0] out \n')
file1.write(');\n')
file1.write('    assign logic[9:0] x_in = x;\n')
file1.write('    assign logic[9:0] y_in = y;\n')
file1.write('    assign logic[18:0] index = y_in * 640 + x_in;\n')
file1.write('\n')
file1.write('always_ff @ (posedge clk)\n')
file1.write('    case (index)\n')
for y in range(height):
    for x in range(width):
          
        hex_index = format(y * width + x, '05x')
        file1.write("      20'h")
        file1.write(hex_index)
        file1.write(': ')
        file1.write("out <= 12'h")
        file1.write(pix_dict[x, y])
        file1.write(';\n')
        
file1.write('    endcase\n')
file1.write('endmodule\n')
print('Done!')
# Out:
# Done!

# %%
pix_dict = {}
im3 = Image.open('out2.png', 'r')
im3.convert('RGB')
width, height = im2.size
pix_val = im2.load()
for y in range(240):
    for x in range(320):
        pix_dict[x, y] = (format((int(pix_val[x, y][0] & 240) >> 4), 'x') + format((int(pix_val[x, y][1] & 240) >> 4), 'x') + format((int(pix_val[x, y][2] & 240) >> 4), 'x'))
        
file4 = open('background.txt', 'w')
for y in range(240):
    for x in range(320):
        file4.write(pix_dict[x, y]+'\n')
file4.close()
print("Done!")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-38-dac676c3b988> in <module>
#       6 for y in range(240):
#       7     for x in range(320):
# ----> 8         pix_dict[x, y] = (format((int(pix_val[x, y][0] & 240) >> 4), 'x') + format((int(pix_val[x, y][1] & 240) >> 4), 'x') + format((int(pix_val[x, y][2] & 240) >> 4), 'x'))
#       9
#      10 file4 = open('background.txt', 'w')
#
# IndexError: image index out of range

# %%
im5 = Image.open('letter_raw.PNG', 'r')
im5.convert('RGB')
pix_dict = {}
width, height = im5.size
pix_val = im5.load()
im6 = Image.new('RGB', (30, 300), 'black')
new_pix_val = im6.load()
for y in range(height):
    for x in range(width):
        if pix_val[x, y][0] == 0:
            new_pix_val[x/width*30, y/height*300] = (255, 255, 255, 255)
        else:
            new_pix_val[x/width*30, y/height*300] = (0, 0, 0, 255)
        print(pix_val[x, y])
im6.save('letter_processed.PNG')
for y in range(300):
    for x in range(30):
        pix_dict[x, y] = (format((int(pix_val[x, y][0] & 240) >> 4), 'x') + format((int(pix_val[x, y][1] & 240) >> 4), 'x') + format((int(pix_val[x, y][2] & 240) >> 4), 'x'))
file5 = open('number.txt', 'w')
for y in range(300):
    for x in range(30):
        file5.write(pix_dict[x, y]+'\n')
file5.close()
print("Done!")
# Out:
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# (255, 255, 255, 255)
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-52-66205e6047c3> in <module>
#      11             new_pix_val[x/width*60, y/height*160] = (255, 255, 255, 255)
#      12         else:
# ---> 13             new_pix_val[x/width*60, y/height*160] = (0, 0, 0, 255)
#      14         print(pix_val[x, y])
#      15 im6.save('letter_processed.PNG')
#
# IndexError: image index out of range
